# %% [markdown]
# # 05 — Model Optimization
#
# Hyperparameter tuning for the best model using GridSearchCV / Optuna.

# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

# TODO: Load features_complete.csv, tune XGBoost
param_grid = {
    'n_estimators': [200, 300, 500],
    'max_depth': [4, 6, 8],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.7, 0.9],
}
print('Parameter grid defined. Load data and run GridSearchCV.')
