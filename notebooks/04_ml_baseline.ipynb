# %% [markdown]
# # 04 — ML Baseline
#
# Train and compare Logistic Regression, Random Forest, XGBoost on stats-only features.

# %%
# Train stats-only baseline
# !python ../models/ml_classification/train.py --no-nlp
# Then evaluate:
# !python ../models/ml_classification/evaluate.py --suffix no_nlp
